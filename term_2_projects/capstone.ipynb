# %% [markdown]
# ### My Computer
# - OS: Ubuntu 18.04.2 LTS 64-bit
# - Memory: 15.6 GiB
# - Processor: Intel® Core™ i5-4460 CPU @ 3.20GHz × 4
# - Graphics: GeForce RTX 2070

# %%
import pandas as pd
import numpy as np
import cv2
import tensorflow.keras.utils as np_utils
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from scipy.io import loadmat
from pathlib import Path
from PIL import Image, ImageFile
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout, GaussianDropout, BatchNormalization, Activation, Dense
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import Xception, InceptionV3
from tensorflow.keras.optimizers import SGD

# %%
# Relevant paths
devkit_path = Path("/media/Data/capstone/car_devkit/devkit")
train_path = Path("/media/Data/capstone/cars_train")
test_path = Path("/media/Data/capstone/cars_test")

# %%
# Load labels
cars_meta = loadmat(devkit_path/"cars_meta.mat")

# Create labels dataframe
cars_info = pd.DataFrame([i[0] for i in cars_meta["class_names"][0]], columns=["class_names"])

# First 5 rows
cars_info.head()
# Out:
#                   class_names
# 0  AM General Hummer SUV 2000
# 1         Acura RL Sedan 2012
# 2         Acura TL Sedan 2012
# 3        Acura TL Type-S 2008
# 4        Acura TSX Sedan 2012

# %%
# Load training info
cars_train_annos = loadmat(devkit_path/"cars_train_annos.mat")

# create training info dataframe
data = [[i.flat[0] for i in row] for row in cars_train_annos["annotations"][0]]
columns = ["bbox_x1", "bbox_y1", "bbox_x2", "bbox_y2", "class_id", "fname"]
train_info = pd.DataFrame(data, columns=columns)

# Update class values since Python index starts from 0
train_info["class_id"] -= 1

# Append train_path to fname
train_info["fname"] = [train_path/f for f in train_info["fname"]]

# Merge labels
train_info = train_info.merge(cars_info, how="inner", left_on="class_id", right_index=True)
train_info = train_info.sort_index()

# First 5 rows
train_info.head()
# Out:
#    bbox_x1  bbox_y1  bbox_x2  bbox_y2  class_id  \
# 0       39      116      569      375        13
# 1       36      116      868      587         2
# 2       85      109      601      381        90
# 3      621      393     1484     1096       133
# 4       14       36      133       99       105
#
#                                        fname  \
# 0  /media/Data/capstone/cars_train/00001.jpg
# 1  /media/Data/capstone/cars_train/00002.jpg
# 2  /media/Data/capstone/cars_train/00003.jpg
# 3  /media/Data/capstone/cars_train/00004.jpg
# 4  /media/Data/capstone/cars_train/00005.jpg
#
#                            class_names
# 0                  Audi TTS Coupe 2012
# 1                  Acura TL Sedan 2012
# 2           Dodge Dakota Club Cab 2007
# 3     Hyundai Sonata Hybrid Sedan 2012
# 4  Ford F-450 Super Duty Crew Cab 2012

# %%
# Load test info with labels
cars_test_annos_withlabels = loadmat(devkit_path/"cars_test_annos_withlabels.mat")

# create test info dataframe
data = [[i.flat[0] for i in row] for row in cars_test_annos_withlabels["annotations"][0]]
columns = ["bbox_x1", "bbox_y1", "bbox_x2", "bbox_y2", "class_id", "fname"]
test_info = pd.DataFrame(data, columns=columns)

# Update class values since Python index starts from 0
test_info["class_id"] -= 1

# Append test_path to fname
test_info["fname"] = [test_path/f for f in test_info["fname"]]

# Merge labels
test_info = test_info.merge(cars_info, how="inner", left_on="class_id", right_index=True)
test_info = test_info.sort_index()

# First 5 rows
test_info.head()
# Out:
#    bbox_x1  bbox_y1  bbox_x2  bbox_y2  class_id  \
# 0       30       52      246      147       180
# 1      100       19      576      203       102
# 2       51      105      968      659       144
# 3       67       84      581      407       186
# 4      140      151      593      339       184
#
#                                       fname  \
# 0  /media/Data/capstone/cars_test/00001.jpg
# 1  /media/Data/capstone/cars_test/00002.jpg
# 2  /media/Data/capstone/cars_test/00003.jpg
# 3  /media/Data/capstone/cars_test/00004.jpg
# 4  /media/Data/capstone/cars_test/00005.jpg
#
#                            class_names
# 0              Suzuki Aerio Sedan 2007
# 1  Ferrari 458 Italia Convertible 2012
# 2                Jeep Patriot SUV 2012
# 3              Toyota Camry Sedan 2012
# 4             Tesla Model S Sedan 2012

# %%
# Descriptive statistics of training images
df = pd.DataFrame(train_info.class_id.value_counts())
df.describe()
# Out:
#         class_id
# count  196.00000
# mean    41.55102
# std      4.33382
# min     24.00000
# 25%     39.75000
# 50%     42.00000
# 75%     44.00000
# max     68.00000

# %%
plt.figure(figsize=(15, 5))
ax = sns.countplot(train_info.class_id)
plt.title("Number of Car Images per Class")
plt.xlabel("Class")
plt.ylabel("Image Count")
plt.xticks([])
plt.show()

# %%
# The function below returns an image and corresponding label at position i from train_info or test_info 
# dataframe for plotting.
# Arg(s):
#     df (pandas.core.frame.DataFrame): train_info or test_info dataframe
#     i (int): element i in the dataframe.
def get_image_info(df, i):
    # Get relevant informations from df.loc[i]
    x1 = df["bbox_x1"][i]
    y1 = df["bbox_y1"][i] 
    x2 = df["bbox_x2"][i] 
    y2 = df["bbox_y2"][i]
    image_path = df["fname"][i]
    title = df["class_names"][i] if (df is train_info) else "Unknown"
    
    # Load colour (BGR) image
    img = cv2.imread(str(image_path))
    
    # Add bounding box to the image
    cv2.rectangle(img, (x1, y1), (x2, y2), (0,0,255), thickness=3)
    
    # Convert BRG image to RGB for plotting
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    return cv_rgb, title

# The function below returns an cropped image and corresponding label at position i from train_info 
# or test_info dataframe for plotting.
# Arg(s):
#     df (pandas.core.frame.DataFrame): train_info or test_info dataframe
#     i (int): element i in the dataframe.
def crop_car_bounding_box(df, i):
    # Get relevant informations from df.loc[i]
    x1 = df["bbox_x1"][i]
    y1 = df["bbox_y1"][i] 
    x2 = df["bbox_x2"][i] 
    y2 = df["bbox_y2"][i]
    image_path = df["fname"][i]
    title = df["class_names"][i] if (df is train_info) else "Unknown"
    
    # Load colour (BGR) image
    img = cv2.imread(str(image_path))
    crop_img = img[y1:y2,x1:x2]
    
    # Convert BRG image to RGB for plotting
    cv_rgb = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    
    return cv_rgb, title

# %%
# Draw first image from training set and test set
fig, ax = plt.subplots(1, 3, figsize=(15,15))
# Draw image from training set
cv_rgb, title = get_image_info(train_info, 0)
ax[0].imshow(cv_rgb)
ax[0].set_title(title)

# Crop car from first image in the training set
cv_rgb, title = crop_car_bounding_box(train_info, 0)
ax[1].imshow(cv_rgb)
ax[1].set_title(title)

# Draw image from test set
cv_rgb, title = get_image_info(test_info, 0)
ax[2].imshow(cv_rgb)
ax[2].set_title(title)

plt.show()

# %%
IMG_HEIGHT, IMG_WIDTH = 299, 299 # For Xception model

# Keras CNN requires a 4D array as input with shape (batch, rows, cols, channels)
# The function below takes a list of string-valued file paths to colour images and return a 4D tensor for Keras CNN
# Arg(s):
#     image_paths: string-valued file paths to colour images
def prepare_tensors_crop_bounding_box(df):
    tensors = []
    for _, index in enumerate(tqdm(df.index)):
        # Get relevant informations from df.loc[i]
        x1 = df.loc[index][0]
        y1 = df.loc[index][1]
        x2 = df.loc[index][2]
        y2 = df.loc[index][3]
        image_path = df.loc[index][4]

        # Load RGB image as PIL.Image.Image type        
        img = image.load_img(image_path)
        
        # Crop bounding box, and resize image to target size
        img = img.resize(size=(IMG_WIDTH, IMG_HEIGHT), resample=Image.LANCZOS, box=(x1,y1,x2,y2))
        
        # Convert PIL.Image.Image type to 3D tensor with shape TARGET_SIZE
        # Rescale the RGB coefficients from range (0, 255) to range (0,1)
        x = image.img_to_array(img)/255.0
        
        # Convert 3D tensor to 4D tensor
        tensors.append(np.expand_dims(x, axis=0))
    return np.vstack(tensors)

# %% [markdown]
# ### Prepare Training, Validation, Test Sets from cropped images

# %%
X, y = train_info.drop(columns=["class_id", "class_names"]), train_info["class_id"]

# Stratify parameter is set to ensure that the train and test sets have approximately the same percentage of 
# samples of each target class as the complete set.
# Split training set into training and validation sets (70% and 30% respectively)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3,
                                                    stratify=np.array(y),
                                                    random_state=40)

# One-hot encoding the classes
N_CLASSES = cars_info.size # 196 classes of cars
y_train_ohe = np_utils.to_categorical(y_train, N_CLASSES)
y_valid_ohe = np_utils.to_categorical(y_valid, N_CLASSES)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True

train_tensors = prepare_tensors_crop_bounding_box(X_train).astype("float32")
valid_tensors = prepare_tensors_crop_bounding_box(X_valid).astype("float32")

print(train_tensors.shape[0], "training samples")
print(valid_tensors.shape[0], "validation samples")
# Out:
# 100%|██████████| 5700/5700 [03:02<00:00, 31.15it/s]
# 100%|██████████| 2444/2444 [01:05<00:00, 40.55it/s]
# 5700 training samples
# 2444 validation samples

# %%
X_test = test_info.drop(columns=["class_id", "class_names"])
y_test = test_info["class_id"]

y_test_ohe = np_utils.to_categorical(y_test, N_CLASSES)

ImageFile.LOAD_TRUNCATED_IMAGES = True

test_tensors = prepare_tensors_crop_bounding_box(X_test).astype("float32")
print(test_tensors.shape[0], "test samples")
# Out:
# 100%|██████████| 8041/8041 [02:47<00:00, 48.07it/s]
# 8041 test samples

# %% [markdown]
# ### Initialise Tensorflow Session

# %%
tf.keras.backend.clear_session()
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
tf.keras.backend.set_session(sess)

# %% [markdown]
# ### Image Augmentation

# %%
# Data Generator for Training and Validation
augmentation_datagen = ImageDataGenerator(
    shear_range=0.2,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest")

# Data Generator for Testing
non_augmentation_datagen = ImageDataGenerator()

# %%
BATCH_SIZE = 32

# Run Training images through the model
train_generator = augmentation_datagen.flow(train_tensors, y_train_ohe, shuffle=False, batch_size=BATCH_SIZE)
train_steps = int(math.ceil(train_tensors.shape[0]/float(BATCH_SIZE)))

# Run Validation images through the model
valid_generator = augmentation_datagen.flow(valid_tensors, y_valid_ohe, shuffle=False, batch_size=BATCH_SIZE)
valid_steps = int(math.ceil(valid_tensors.shape[0]/float(BATCH_SIZE)))

# %% [markdown]
# ### Benchmarking Model

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding="same", activation="relu", input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=32, kernel_size=2, padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=64, kernel_size=2, padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(N_CLASSES, activation="softmax"))

model.summary()

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 299, 299, 16)      208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 149, 149, 32)      2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 74, 74, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               44859904
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 44,970,996
# Trainable params: 44,970,996
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 5

checkpointer = ModelCheckpoint(filepath="benchmark.weights.best.hdf5", 
                               monitor="val_loss", 
                               save_best_only=True, 
                               verbose=1)

benchmark = model.fit_generator(train_generator,
                    steps_per_epoch=train_steps,
                    epochs=EPOCHS, verbose=1, callbacks=[checkpointer],
                    validation_data=valid_generator,
                    validation_steps=valid_steps)
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 77/77 [==============================] - 38s 494ms/step - loss: 5.2345 - acc: 0.0147
#
# Epoch 00001: val_loss improved from inf to 5.23450, saving model to benchmark.weights.best.hdf5
# 179/179 [==============================] - 122s 681ms/step - loss: 6.1770 - acc: 0.0068 - val_loss: 5.2345 - val_acc: 0.0147
# Epoch 2/5
# 77/77 [==============================] - 37s 487ms/step - loss: 5.1513 - acc: 0.0168
#
# Epoch 00002: val_loss improved from 5.23450 to 5.15129, saving model to benchmark.weights.best.hdf5
# 179/179 [==============================] - 119s 663ms/step - loss: 5.1688 - acc: 0.0151 - val_loss: 5.1513 - val_acc: 0.0168
# Epoch 3/5
# 77/77 [==============================] - 36s 466ms/step - loss: 5.1519 - acc: 0.0176
#
# Epoch 00003: val_loss did not improve from 5.15129
# 179/179 [==============================] - 114s 640ms/step - loss: 5.1162 - acc: 0.0177 - val_loss: 5.1519 - val_acc: 0.0176
# Epoch 4/5
# 77/77 [==============================] - 36s 465ms/step - loss: 5.0891 - acc: 0.0172
#
# Epoch 00004: val_loss improved from 5.15129 to 5.08908, saving model to benchmark.weights.best.hdf5
# 179/179 [==============================] - 115s 641ms/step - loss: 5.0847 - acc: 0.0196 - val_loss: 5.0891 - val_acc: 0.0172
# Epoch 5/5
# 77/77 [==============================] - 36s 467ms/step - loss: 5.1117 - acc: 0.0221
#
# Epoch 00005: val_loss did not improve from 5.08908
# 179/179 [==============================] - 115s 642ms/step - loss: 5.0539 - acc: 0.0223 - val_loss: 5.1117 - val_acc: 0.0221

# %% [markdown]
# ### Test Benchmarking Model Against Test Set

# %%
# Load the weights that yielded the best validation accuracy
model.load_weights("benchmark.weights.best.hdf5")

# Evaluate and print public test accuracy
score = model.evaluate(test_tensors, y_test_ohe, verbose=0)
print("Test accuracy:", score[1])
# Out:
# Test accuracy: 0.01927621

# %% [markdown]
# ### Xception Fine-tuned Model

# %%
# Xception
Xception_model = Xception(weights="imagenet", include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
for i, layer in enumerate(Xception_model.layers):
    if i < 94: layer.trainable = False
    else: layer.trainable = True

model = Sequential()
model.add(Xception_model)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(rate=0.5))
model.add(Dense(256, activation="relu", kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(rate=0.5))
model.add(Dense(N_CLASSES, activation="softmax"))

# Set optimizer
optimizer = SGD(lr=1e-2, momentum=0.9, decay=1e-6)

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Model)             (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# batch_normalization_v1_4 (Ba (None, 10, 10, 2048)      8192
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 196)               50372
# =================================================================
# Total params: 22,100,460
# Trainable params: 11,252,676
# Non-trainable params: 10,847,784
# _________________________________________________________________

# %%
EPOCHS = 70
ES_PATIENCE = 10 # EarlyStopping patience value
RLROP_PATIENCE = 3 # ReduceLROnPlateau patience value
RLROP_FACTOR = 0.2 # ReduceLROnPlateau factor value

callbacks = [ModelCheckpoint(filepath="Xception_FT.weights.best.hdf5", 
                             monitor="val_loss", 
                             save_best_only=True, 
                             verbose=1),
             EarlyStopping(monitor="val_acc", 
                           patience=ES_PATIENCE, 
                           min_delta=1e-3, 
                           restore_best_weights=True,
                           verbose=1),
             ReduceLROnPlateau(monitor="val_loss", 
                               patience=RLROP_PATIENCE, 
                               factor=RLROP_FACTOR, 
                               verbose=1)
            ]

# Train the model
history = model.fit_generator(train_generator,
                    steps_per_epoch=train_steps,
                    epochs=EPOCHS, verbose=1, callbacks=callbacks,
                    validation_data=valid_generator,
                    validation_steps=valid_steps)
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/70
# 77/77 [==============================] - 37s 481ms/step - loss: 10.9700 - acc: 0.0348
#
# Epoch 00001: val_loss improved from inf to 10.97002, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 121s 678ms/step - loss: 13.8325 - acc: 0.0111 - val_loss: 10.9700 - val_acc: 0.0348
# Epoch 2/70
# 77/77 [==============================] - 36s 462ms/step - loss: 7.5852 - acc: 0.0450
#
# Epoch 00002: val_loss improved from 10.97002 to 7.58525, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 637ms/step - loss: 9.1744 - acc: 0.0253 - val_loss: 7.5852 - val_acc: 0.0450
# Epoch 3/70
# 77/77 [==============================] - 35s 460ms/step - loss: 5.7531 - acc: 0.1007
#
# Epoch 00003: val_loss improved from 7.58525 to 5.75314, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 638ms/step - loss: 6.6534 - acc: 0.0509 - val_loss: 5.7531 - val_acc: 0.1007
# Epoch 4/70
# 77/77 [==============================] - 36s 463ms/step - loss: 4.7681 - acc: 0.1289
#
# Epoch 00004: val_loss improved from 5.75314 to 4.76813, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 637ms/step - loss: 5.2485 - acc: 0.0900 - val_loss: 4.7681 - val_acc: 0.1289
# Epoch 5/70
# 77/77 [==============================] - 36s 464ms/step - loss: 4.3011 - acc: 0.1420
#
# Epoch 00005: val_loss improved from 4.76813 to 4.30109, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 638ms/step - loss: 4.4170 - acc: 0.1388 - val_loss: 4.3011 - val_acc: 0.1420
# Epoch 6/70
# 77/77 [==============================] - 35s 460ms/step - loss: 3.7886 - acc: 0.2201
#
# Epoch 00006: val_loss improved from 4.30109 to 3.78865, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 636ms/step - loss: 3.8512 - acc: 0.2002 - val_loss: 3.7886 - val_acc: 0.2201
# Epoch 7/70
# 77/77 [==============================] - 35s 460ms/step - loss: 3.6135 - acc: 0.2590
#
# Epoch 00007: val_loss improved from 3.78865 to 3.61354, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 637ms/step - loss: 3.4655 - acc: 0.2505 - val_loss: 3.6135 - val_acc: 0.2590
# Epoch 8/70
# 77/77 [==============================] - 36s 466ms/step - loss: 3.3120 - acc: 0.3175
#
# Epoch 00008: val_loss improved from 3.61354 to 3.31200, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 115s 643ms/step - loss: 3.1326 - acc: 0.3151 - val_loss: 3.3120 - val_acc: 0.3175
# Epoch 9/70
# 77/77 [==============================] - 36s 465ms/step - loss: 3.2618 - acc: 0.3040
#
# Epoch 00009: val_loss improved from 3.31200 to 3.26177, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] -
saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 637ms/step - loss: 0.8293 - acc: 0.9168 - val_loss: 1.8409 - val_acc: 0.6326
# Epoch 32/70
# 77/77 [==============================] - 36s 462ms/step - loss: 1.7729 - acc: 0.6399
#
# Epoch 00032: val_loss improved from 1.84086 to 1.77288, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 637ms/step - loss: 0.7903 - acc: 0.9240 - val_loss: 1.7729 - val_acc: 0.6399
# Epoch 33/70
# 77/77 [==============================] - 36s 461ms/step - loss: 1.8420 - acc: 0.6109
#
# Epoch 00033: val_loss did not improve from 1.77288
# 179/179 [==============================] - 113s 634ms/step - loss: 0.7715 - acc: 0.9233 - val_loss: 1.8420 - val_acc: 0.6109
# Epoch 34/70
# 77/77 [==============================] - 36s 462ms/step - loss: 1.8032 - acc: 0.6219
#
# Epoch 00034: val_loss did not improve from 1.77288
# 179/179 [==============================] - 114s 638ms/step - loss: 0.7553 - acc: 0.9221 - val_loss: 1.8032 - val_acc: 0.6219
# Epoch 35/70
# 77/77 [==============================] - 36s 464ms/step - loss: 1.7454 - acc: 0.6350
#
# Epoch 00035: val_loss improved from 1.77288 to 1.74542, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 636ms/step - loss: 0.7295 - acc: 0.9275 - val_loss: 1.7454 - val_acc: 0.6350
# Epoch 36/70
# 77/77 [==============================] - 35s 460ms/step - loss: 1.7966 - acc: 0.6289
#
# Epoch 00036: val_loss did not improve from 1.74542
# 179/179 [==============================] - 114s 637ms/step - loss: 0.7000 - acc: 0.9391 - val_loss: 1.7966 - val_acc: 0.6289
# Epoch 37/70
# 77/77 [==============================] - 36s 468ms/step - loss: 1.7342 - acc: 0.6350
#
# Epoch 00037: val_loss improved from 1.74542 to 1.73425, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 114s 637ms/step - loss: 0.6983 - acc: 0.9340 - val_loss: 1.7342 - val_acc: 0.6350
# Epoch 38/70
# 77/77 [==============================] - 36s 465ms/step - loss: 1.6543 - acc: 0.6522
#
# Epoch 00038: val_loss improved from 1.73425 to 1.65431, saving model to Xception_FT.weights.best.hdf5
# 179/179 [==============================] - 115s 640ms/step - loss: 0.6893 - acc: 0.9337 - val_loss: 1.6543 - val_acc: 0.6522
# Epoch 39/70
# 77/77 [==============================] - 37s 474ms/step - loss: 1.6886 - acc: 0.6477
#
# Epoch 00039: val_loss did not improve from 1.65431
# 179/179 [==============================] - 115s 641ms/step - loss: 0.6797 - acc: 0.9351 - val_loss: 1.6886 - val_acc: 0.6477
# Epoch 40/70
# 77/77 [==============================] - 36s 461ms/step - loss: 1.7857 - acc: 0.6129
#
# Epoch 00040: val_loss did not improve from 1.65431
# 179/179 [==============================] - 115s 640ms/step - loss: 0.6586 - acc: 0.9405 - val_loss: 1.7857 - val_acc: 0.6129
# Epoch 41/70
# 77/77 [==============================] - 36s 461ms/step - loss: 1.7047 - acc: 0.6277
#
# Epoch 00041: val_loss did not improve from 1.65431
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 179/179 [==============================] - 115s 640ms/step - loss: 0.6498 - acc: 0.9416 - val_loss: 1.7047 - val_acc: 0.6277
# Epoch 42/70
# 77/77 [==============================] - 36s 464ms/step - loss: 1.7056 - acc: 0.6387
#
# Epoch 00042: val_loss did not improve from 1.65431
# 179/179 [==============================] - 115s 642ms/step - loss: 0.6292 - acc: 0.9475 - val_loss: 1.7056 - val_acc: 0.6387
# Epoch 43/70
# 77/77 [==============================] - 36s 464ms/step - loss: 1.7242 - acc: 0.6301
#
# Epoch 00043: val_loss did not improve from 1.65431
# 179/179 [==============================] - 115s 640ms/step - loss: 0.6219 - acc: 0.9535 - val_loss: 1.7242 - val_acc: 0.6301
# Epoch 44/70
# 77/77 [==============================] - 36s 465ms/step - loss: 1.6872 - acc: 0.6416
#
# Epoch 00044: val_loss did not improve from 1.65431
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 179/179 [==============================] - 114s 638ms/step - loss: 0.6118 - acc: 0.9551 - val_loss: 1.6872 - val_acc: 0.6416
# Epoch 45/70
# 77/77 [==============================] - 36s 463ms/step - loss: 1.6873 - acc: 0.6350
#
# Epoch 00045: val_loss did not improve from 1.65431
# 179/179 [==============================] - 114s 637ms/step - loss: 0.6228 - acc: 0.9482 - val_loss: 1.6873 - val_acc: 0.6350
# Epoch 46/70
# 77/77 [==============================] - 35s 460ms/step - loss: 1.6914 - acc: 0.6440
#
# Epoch 00046: val_loss did not improve from 1.65431
# 179/179 [==============================] - 114s 636ms/step - loss: 0.6194 - acc: 0.9511 - val_loss: 1.6914 - val_acc: 0.6440
# Epoch 47/70
# 77/77 [==============================] - 35s 459ms/step - loss: 1.6647 - acc: 0.6420
#
# Epoch 00047: val_loss did not improve from 1.65431
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# 179/179 [==============================] - 113s 633ms/step - loss: 0.6084 - acc: 0.9547 - val_loss: 1.6647 - val_acc: 0.6420
# Epoch 48/70
# 77/77 [==============================] - 36s 463ms/step - loss: 1.6962 - acc: 0.6223
#
# Epoch 00048: val_loss did not improve from 1.65431
# Restoring model weights from the end of the best epoch.
# 179/179 [==============================] - 114s 636ms/step - loss: 0.6238 - acc: 0.9467 - val_loss: 1.6962 - val_acc: 0.6223
# Epoch 00048: early stopping

# %% [markdown]
# ### Evaluation of Xception Fine-tuned Model

# %%
# Model evaluation
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle("Model Performance", fontsize=12)
acc = history.history["acc"]
val_acc = history.history["val_acc"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(1,len(acc)+1)
ax1.plot(epochs, acc, label="Train Accuracy")
ax1.plot(epochs, val_acc, label="Validation Accuracy")
ax1.set_ylabel("Accuracy Value")
ax1.set_xlabel("Epoch")
ax1.set_title("Accuracy")
l1 = ax1.legend(loc="best")

ax2.plot(epochs, loss, label="Train Loss")
ax2.plot(epochs, val_loss, label="Validation Loss")
ax2.set_ylabel("Loss Value")
ax2.set_xlabel("Epoch")
ax2.set_title("Loss")
l2 = ax2.legend(loc="best")

# %% [markdown]
# ### Test Xception Fine-tuned Model against Test Set

# %%
# Load the weights that yielded the best validation accuracy
model.load_weights("Xception_FT.weights.best.hdf5")

# Evaluate and print public test accuracy
score = model.evaluate(test_tensors, y_test_ohe, verbose=0)
print("Test accuracy:", score[1])
# Out:
# Test accuracy: 0.7246611

# %% [markdown]
# ### InceptionV3 Fine-tuned Model

# %%
# InceptionV3
InceptionV3_model = InceptionV3(weights="imagenet", include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
for i, layer in enumerate(InceptionV3_model.layers):
    if i < 250: layer.trainable = False
    else: layer.trainable = True

model = Sequential()
model.add(InceptionV3_model)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation="relu"))
model.add(Dropout(rate=0.5))
model.add(Dense(512, activation="relu"))
model.add(Dropout(rate=0.5))
model.add(Dense(N_CLASSES, activation="softmax"))

# Model summary
model.summary()

# Set optimizer
optimizer = SGD(lr=1e-2, momentum=0.9, decay=1e-6)

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# batch_normalization_v1_94 (B (None, 8, 8, 2048)        8192
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 196)               100548
# =================================================================
# Total params: 23,223,268
# Trainable params: 11,957,828
# Non-trainable params: 11,265,440
# _________________________________________________________________

# %%
EPOCHS = 70
ES_PATIENCE = 10 # EarlyStopping patience value
RLROP_PATIENCE = 3 # ReduceLROnPlateau patience value
RLROP_FACTOR = 0.2 # ReduceLROnPlateau factor value

callbacks = [ModelCheckpoint(filepath="InceptionV3_FT.weights.best.hdf5", 
                             monitor="val_loss", 
                             save_best_only=True, 
                             verbose=1),
             EarlyStopping(monitor="val_acc", 
                           patience=ES_PATIENCE, 
                           min_delta=1e-3, 
                           restore_best_weights=True,
                           verbose=1),
             ReduceLROnPlateau(monitor="val_loss", 
                               patience=RLROP_PATIENCE, 
                               factor=RLROP_FACTOR, 
                               verbose=1)
            ]

# Train the model
history = model.fit_generator(train_generator,
                    steps_per_epoch=train_steps,
                    epochs=EPOCHS, verbose=1, callbacks=callbacks,
                    validation_data=valid_generator,
                    validation_steps=valid_steps)
# Out:
# WARNING:tensorflow:From /home/leovan/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/70
# 77/77 [==============================] - 38s 488ms/step - loss: 5.1125 - acc: 0.0135
#
# Epoch 00001: val_loss improved from inf to 5.11254, saving model to InceptionV3_FT.weights.best.hdf5
# 179/179 [==============================] - 129s 720ms/step - loss: 5.2821 - acc: 0.0118 - val_loss: 5.1125 - val_acc: 0.0135
# Epoch 2/70
# 77/77 [==============================] - 37s 476ms/step - loss: 4.4812 - acc: 0.0540
#
# Epoch 00002: val_loss improved from 5.11254 to 4.48120, saving model to InceptionV3_FT.weights.best.hdf5
# 179/179 [==============================] - 118s 659ms/step - loss: 4.8145 - acc: 0.0407 - val_loss: 4.4812 - val_acc: 0.0540
# Epoch 3/70
# 77/77 [==============================] - 37s 478ms/step - loss: 4.1741 - acc: 0.0949
#
# Epoch 00003: val_loss improved from 4.48120 to 4.17414, saving model to InceptionV3_FT.weights.best.hdf5
# 179/179 [==============================] - 118s 660ms/step - loss: 4.2006 - acc: 0.0905 - val_loss: 4.1741 - val_acc: 0.0949
# Epoch 4/70
# 77/77 [==============================] - 37s 479ms/step - loss: 3.6393 - acc: 0.1583
#
# Epoch 00004: val_loss improved from 4.17414 to 3.63928, saving model to InceptionV3_FT.weights.best.hdf5
# 179/179 [==============================] - 118s 661ms/step - loss: 3.6418 - acc: 0.1509 - val_loss: 3.6393 - val_acc: 0.1583
# Epoch 5/70
# 77/77 [==============================] - 37s 476ms/step - loss: 3.8781 - acc: 0.1424
#
# Epoch 00005: val_loss did not improve from 3.63928
# 179/179 [==============================] - 119s 663ms/step - loss: 3.1551 - acc: 0.2200 - val_loss: 3.8781 - val_acc: 0.1424
# Epoch 6/70
# 77/77 [==============================] - 37s 479ms/step - loss: 3.2899 - acc: 0.2070
#
# Epoch 00006: val_loss improved from 3.63928 to 3.28985, saving model to InceptionV3_FT.weights.best.hdf5
# 179/179 [==============================] - 118s 659ms/step - loss: 2.8027 - acc: 0.2849 - val_loss: 3.2899 - val_acc: 0.2070
# Epoch 7/70
# 77/77 [==============================] - 37s 479ms/step - loss: 2.8669 - acc: 0.2766
#
# Epoch 00007: val_loss improved from 3.28985 to 2.86690, saving model to InceptionV3_FT.weights.best.hdf5
# 179/179 [==============================] - 118s
val_loss did not improve from 1.96706
# 179/179 [==============================] - 117s 654ms/step - loss: 0.5982 - acc: 0.8116 - val_loss: 2.0582 - val_acc: 0.4840
# Epoch 30/70
# 77/77 [==============================] - 37s 477ms/step - loss: 2.0697 - acc: 0.4926
#
# Epoch 00030: val_loss did not improve from 1.96706
# 179/179 [==============================] - 116s 651ms/step - loss: 0.6069 - acc: 0.8109 - val_loss: 2.0697 - val_acc: 0.4926
# Epoch 31/70
# 77/77 [==============================] - 36s 470ms/step - loss: 2.0389 - acc: 0.4885
#
# Epoch 00031: val_loss did not improve from 1.96706
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# 179/179 [==============================] - 116s 650ms/step - loss: 0.6228 - acc: 0.8002 - val_loss: 2.0389 - val_acc: 0.4885
# Epoch 32/70
# 77/77 [==============================] - 37s 477ms/step - loss: 2.1153 - acc: 0.4873
#
# Epoch 00032: val_loss did not improve from 1.96706
# 179/179 [==============================] - 117s 656ms/step - loss: 0.6021 - acc: 0.8121 - val_loss: 2.1153 - val_acc: 0.4873
# Epoch 33/70
# 77/77 [==============================] - 37s 476ms/step - loss: 2.0369 - acc: 0.4820
#
# Epoch 00033: val_loss did not improve from 1.96706
# 179/179 [==============================] - 117s 654ms/step - loss: 0.6100 - acc: 0.8082 - val_loss: 2.0369 - val_acc: 0.4820
# Epoch 34/70
# 77/77 [==============================] - 37s 475ms/step - loss: 2.0544 - acc: 0.4894
#
# Epoch 00034: val_loss did not improve from 1.96706
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# 179/179 [==============================] - 117s 653ms/step - loss: 0.6180 - acc: 0.8042 - val_loss: 2.0544 - val_acc: 0.4894
# Epoch 35/70
# 77/77 [==============================] - 37s 478ms/step - loss: 2.0564 - acc: 0.4832
#
# Epoch 00035: val_loss did not improve from 1.96706
# Restoring model weights from the end of the best epoch.
# 179/179 [==============================] - 118s 657ms/step - loss: 0.6066 - acc: 0.8139 - val_loss: 2.0564 - val_acc: 0.4832
# Epoch 00035: early stopping

# %% [markdown]
# ### Evaluation of InceptionV3 Fine-tuned Model

# %%
# Model evaluation
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle("Model Performance", fontsize=12)
acc = history.history["acc"]
val_acc = history.history["val_acc"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(1,len(acc)+1)
ax1.plot(epochs, acc, label="Train Accuracy")
ax1.plot(epochs, val_acc, label="Validation Accuracy")
ax1.set_ylabel("Accuracy Value")
ax1.set_xlabel("Epoch")
ax1.set_title("Accuracy")
l1 = ax1.legend(loc="best")

ax2.plot(epochs, loss, label="Train Loss")
ax2.plot(epochs, val_loss, label="Validation Loss")
ax2.set_ylabel("Loss Value")
ax2.set_xlabel("Epoch")
ax2.set_title("Loss")
l2 = ax2.legend(loc="best")

# %% [markdown]
# ### Test InceptionV3 Fine-tuned Model against Test Set

# %%
# Load the weights that yielded the best validation accuracy
model.load_weights("InceptionV3_FT.weights.best.hdf5")

# Evaluate and print public test accuracy
score = model.evaluate(test_tensors, y_test_ohe, verbose=0)
print("Test accuracy:", score[1])
# Out:
# Test accuracy: 0.57704264

# %% [markdown]
# ### Training Accuracy Comparison
#
# |Model|Training|Validation|Test|
# |:-:|:-:|:-:|:-:|
# |Benchmarking|1.96%|1.72%|1.93%|
# |Fine-tuned Xception|93.37%|65.22%|72.47%|
# |Fine-tuned InceptionV3|72.68%|49.10%|57.70%|

# %% [markdown]
# ### Reference:
# - [Xception: Deep Learning with Depthwise Separable Convolutions](https://arxiv.org/abs/1610.02357)
